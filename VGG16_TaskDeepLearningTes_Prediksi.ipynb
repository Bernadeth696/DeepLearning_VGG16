# %% [markdown]
# <a href="https://colab.research.google.com/github/Bernadeth696/DeepLearning_VGG16/blob/master/VGG16_TaskDeepLearningTes_Prediksi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MELAKUKAN PREDIKSI**

# %%
# import library
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/dataset/deep_learning/tes1/simpan_Model'

# %%
# memuat dan menampung model yang telah disimpan dalam format .h5
model = tf.keras.models.load_model(path+'/vgg16.h5')

# %%
# mendefinisikan kelas target terbagi 2 kelas
class_names = ['motor', 'mobil']

# %%
#mendefinisikan path ke folder yang berisi gambar
img_folder ='/content/drive/MyDrive/dataset/deep_learning/tes1/testing/mobil'

# %%
# mendapatkan daftar nama file pada folder
img_files = os.listdir(img_folder)

# %%
# memilih 3 gambar secara acak dalam folder testing mobil
img_files = np.random.choice(img_files, size=1, replace=False)

# %%
# menampilkan gambar dan hasil prediksi untuk setiap gambar
for img_file in img_files:
    #memuat gambar
    img_path = os.path.join(img_folder, img_file)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))

    # merubah gambar menjadi array numpy
    img_array = np.array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # melakukan prediksi menggunakan model
    predictions = model.predict(img_array)

    #ambil indeks kelas dengan probabilitas tertinggi
    predicted_class = np.argmax(predictions[0])
# Out:
# 1/1 [==============================] - 1s 614ms/step

# %%
print("Hasil Prediksi Untuk Gambar {} adalah: {}".format(img_file, class_names[predicted_class]))
plt.imshow(img)
plt.show()
# Out:
# Hasil Prediksi Untuk Gambar mobil (92).jpg adalah: mobil
